# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/jorgepereira96/SAD_JorgePereira/blob/master/aulaPratica01.ipynb)

# %%
import sklearn.datasets as datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

"done"
# Out:
# 'done'

# %%
#preço maximo, minimo e médio

data= datasets.california_housing.fetch_california_housing()

new_data= np.concatenate((data.data, data.target.reshape(-1,1)*100000), axis=1)

names= data.feature_names + ["Preços"]

dframe= pd.DataFrame(data= new_data, columns= names)

price= dframe.loc[0:,["Preços"]]

#maximum= pd.DataFrame.max(price)
#minimum= pd.DataFrame.min(price)
#mean= pd.DataFrame.mean(price)

price.aggregate(['max','min','mean'])
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data
#              Preços
# max   500001.000000
# min    14999.000000
# mean  206855.816909

# %%
#média da população do dataset

population= dframe.loc[0:,["Population"]]

#popMean= pd.DataFrame.mean(population)

population.aggregate(['mean'])
# Out:
#        Population
# mean  1425.476744

# %%
#média do número de quartos para ocupações médias de 1,2,3,4 e 5 pessoas

AveOccup= dframe.loc[dframe["AveOccup"].isin([1,2,3,4,5])]

AveOccup.loc[0:,["AveRooms"]]
# Out:
#         AveRooms
# 328     4.880702
# 1284    3.823308
# 1484    4.577236
# 1867   23.888889
# 1903   11.679878
# 2564    5.333333
# 2907    5.425993
# 3009    3.971831
# 3126    1.000000
# 3682    4.878788
# 4122    3.043956
# 4609    1.972644
# 4968    3.377922
# 5182    3.670330
# 5318    5.494845
# 5341    4.571429
# 5618    2.565217
# 5744    4.486280
# 6089    6.045918
# 6172    5.161172
# 6450    6.537459
# 6881    4.085271
# 6967    4.297357
# 7367    4.444795
# 8395    6.900000
# 8474    4.751563
# 8723    5.496933
# 8875    8.948148
# 9052    5.714286
# 9231    5.661972
# ...          ...
# 11468   5.263926
# 11605  10.500000
# 11700   5.071698
# 11890   4.778689
# 11950   5.901381
# 12286   3.000000
# 12371  13.408082
# 12408   5.207101
# 12467   5.233184
# 12642   5.170819
# 13069   4.098667
# 13294   6.018692
# 13313   4.231810
# 13979  14.000000
# 14059   4.278926
# 14486   8.267327
# 14799   3.744828
# 15293   6.626566
# 15444   5.036398
# 15463   5.268041
# 17071   5.041096
# 17309   4.474820
# 17788   4.488027
# 18210   4.500000
# 18516   5.264840
# 18578   4.214751
# 18944   6.770492
# 19444   5.023684
# 19784   7.911111
# 20038   4.845921
#
# [63 rows x 1 columns]
